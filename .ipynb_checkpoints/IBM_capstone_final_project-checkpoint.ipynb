# %% [markdown]
# # Introduction/Business Problem
#
# I would like to compare and determine the best neighborhood in San Antonio, TX for tourists. San Antonio is a big city with a number of tourist sites. It has a local NBA team San Antonio Spurs, which draws NBA fans from all over the world each year. Moreover, with the historical connection with Mexican culture, the Mexican food there is a must try. I hope to give tourists a good recommendation on where to stay given their specific interests in the city.
#
# Whether the focus is on food, tourist sites, or watching NBA games, I would like to let the users to have the power to assign their priority and recommend neighborhoods accordingly. I believe this added flexibility will let this project help many people who visit San Antonio.

# %% [markdown]
# # Data
#
# To do so, we need to first define the neighborhoods in San Antonio. The definition of it will come from www.sanantonio.com/neighborhoods, which gives 9 of it. I will first determine the coordinates of these 9 neighborhoods. Then, for each neighborhood, I shall explore the nearby venues. Given that people usually drive in San Antonio, we may be able to set a larger radius, say 2 miles for now. I am also contemplating searching through the city and give scores based on the distance.
#
# Given user-assigned priority, I would like to return the neighborhood with the highest score.

# %% [markdown]
# ## Data collection
#
# We will start with getting the coordinates of the neighborhoods.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'AJCE4HY4IAPY3NGK0GR525M1OA2BF45G0TI4HUONPJVGL0PM' # your Foursquare ID
CLIENT_SECRET = 'J022B41DX1EFZS3ANDVM2IAQAGQQAEZEQU2SZ3WJTHAYWBFB' # your Foursquare Secret
VERSION = '20201031'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AJCE4HY4IAPY3NGK0GR525M1OA2BF45G0TI4HUONPJVGL0PM
# CLIENT_SECRET:J022B41DX1EFZS3ANDVM2IAQAGQQAEZEQU2SZ3WJTHAYWBFB

# %%
address = 'San Antonio, TX'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude_SA = location.latitude
longitude_SA = location.longitude
print(latitude_SA, longitude_SA)
# Out:
# 29.4246002 -98.4951405

# %%
neighborhoods = ['Northwest Side', 'Uptown', 'Southside', 'Midtown', 'North Central', 'Alamo Heights', 'East Side', 'Near East Side', 'Downtown']

latitudes = []
longitudes = []

for neighborhood in neighborhoods:
    address_now = neighborhood + ', ' + address
    #geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address_now)
    try:
        latitudes.append(location.latitude)
    except:
        latitudes.append(0)
    try:
        longitudes.append(location.longitude)
    except:
        longitudes.append(0)
    print(latitudes[-1],longitudes[-1])

    
#Since the geolocator cannot find the coordinate of North Central, I have  to key in manually.
latitudes[0] = 29.557154
longitudes[0] = -98.614671

latitudes[1], longitudes[1] = 29.507220, -98.462190
latitudes[2], longitudes[2] = 29.333650, -98.524594
latitudes[4] = 29.497288
longitudes[4] = -98.525972

latitudes[6], longitudes[6] = 29.406447, -98.418599
latitudes[7], longitudes[7] = 29.441394, -98.450757
    
print(latitudes)
print(longitudes)
# Out:
# 32.7961145 -97.3380154
# 26.18995915 -97.6905124964365
# 26.1564641 -98.1233416
# 29.4534589 -98.4946316
# 0 0
# 29.4832264 -98.468455
# 33.21574364999999 -97.13152896976189
# 33.21574364999999 -97.13152896976189
# 29.4257188 -98.4892023
# [29.557154, 29.50722, 29.33365, 29.4534589, 29.497288, 29.4832264, 29.406447, 29.441394, 29.4257188]
# [-98.614671, -98.46219, -98.524594, -98.4946316, -98.525972, -98.468455, -98.418599, -98.450757, -98.4892023]

# %%
df_hood = pd.DataFrame(data = {'Neighborhood':neighborhoods, 'Latitude': latitudes, 'Longitude':longitudes})
df_hood
# Out:
#      Neighborhood   Latitude  Longitude
# 0  Northwest Side  29.557154 -98.614671
# 1          Uptown  29.507220 -98.462190
# 2       Southside  29.333650 -98.524594
# 3         Midtown  29.453459 -98.494632
# 4   North Central  29.497288 -98.525972
# 5   Alamo Heights  29.483226 -98.468455
# 6       East Side  29.406447 -98.418599
# 7  Near East Side  29.441394 -98.450757
# 8        Downtown  29.425719 -98.489202

# %% [markdown]
# We will start by looking for restaurants nearby.

# %%
search_query = 'Restaurant'
radius = 3000
LIMIT = 25

# %%
def getNearbyVenues(names, latitudes, longitudes, search_query, LIMIT, radius=3000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            search_query,
            radius, 
            LIMIT)
            
        # make the GET request
        #results = requests.get(url).json()["response"]['groups'][0]['items']
        results = requests.get(url).json()["response"]['venues']
        
        # return only relevant information for each nearby venue
        
        for v in results:
            try:
                categories_list = v['categories']
            except:
                categories_list = v['venue.categories']

            if len(categories_list) == 0:
                cat_name = None
            else:
                cat_name = categories_list[0]['name']
            
            venues_list.append((name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],  
            cat_name,
            v['id']))
        
        #venues_list.append([(
        #    name, 
        #    lat, 
        #    lng, 
        #    v['name'], 
        #    v['location']['lat'], 
        #    v['location']['lng'],  
        #    v['categories'][0]['name']) for v in results])

    #nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues = pd.DataFrame(item for item in venues_list)
    nearby_venues.columns = ['Neighborhood', 
                  'Neighrborhood Latitude', 
                  'Neighrborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category',
                    'Venue ID']
    
    return(nearby_venues)

# %%
search_query = 'Restaurant'
df_food = getNearbyVenues(df_hood.Neighborhood, df_hood.Latitude, df_hood.Longitude, search_query, LIMIT, radius)
df_food.head()
# Out:
# Northwest Side
# Uptown
# Southside
# Midtown
# North Central
# Alamo Heights
# East Side
# Near East Side
# Downtown
#      Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0  Northwest Side               29.557154               -98.614671
# 1  Northwest Side               29.557154               -98.614671
# 2  Northwest Side               29.557154               -98.614671
# 3  Northwest Side               29.557154               -98.614671
# 4  Northwest Side               29.557154               -98.614671
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0  Los Jalapenos Mexican Restaurant       29.543234       -98.613792
# 1         Rico's Mexican Restaurant       29.555711       -98.614597
# 2       Don Jose Mexican Restaurant       29.554323       -98.615431
# 3             Twin Peaks Restaurant       29.562585       -98.591814
# 4                Tommy’s Restaurant       29.565912       -98.593985
#
#         Venue Category                  Venue ID
# 0   Mexican Restaurant  4b7ff425f964a520a54630e3
# 1   Mexican Restaurant  4ff327ece4b0f1c616d33fb2
# 2   Mexican Restaurant  4f44ab7919836ed00195b2e8
# 3  American Restaurant  4e83ac9af790caced93b3fe3
# 4   Mexican Restaurant  5a96c81967e5f23b82f51ecd

# %%
df_food.head(50)
# Out:
#       Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 
# 24  Formosa Garden Chinese and Hibachi Restaurant       29.516860
# 25                     Maria's Mexican Restaurant       29.487385
# 26                       Raffles Restaurant & Bar       29.516486
# 27                   La Gloria Mexican Restaurant       29.526350
# 28                            Solarium Restaurant       29.518402
# 29                   Crumpets Restaurant & Bakery       29.506111
# 30                            Joseph's Restaurant       29.517887
# 31                 Twin Dragon Chinese Restaurant       29.518789
# 32                              Quarry Restaurant       29.498060
# 33   Piranha Killer Sushi Restaurant & Happy Hour       29.494236
# 34                         Tong's Thai Restaurant       29.486565
# 35                        Eeho Mexican Restaurant       29.525200
# 36                               Jim's Restaurant       29.515101
# 37                            Adelante Restaurant       29.490842
# 38                       Paesanos Lincoln Heights       29.498520
# 39                           El Chapal Restaurant       29.491445
# 40                     L'Etoile French Restaurant       29.483940
# 41                       Ala's Mexican Restaurant       29.489523
# 42                            Acapulco Restaurant       29.489155
# 43              La Posada Del Rey Mexican Cuisine       29.497528
# 44                               Quarry Golf Club       29.496915
# 45                                    Frederick's       29.499709
# 46                      Canton Chinese Restaurant       29.515982
# 47                                         Piatti       29.496251
# 48                           Taco Port Restaurant       29.527674
# 49                          Papouli's Greek Grill       29.495370
#
#     Venue Longitude                 Venue Category
# 0        -98.613792             Mexican Restaurant
# 1        -98.614597             Mexican Restaurant
# 2        -98.615431             Mexican Restaurant
# 3        -98.591814            American Restaurant
# 4        -98.593985             Mexican Restaurant
# 5        -98.613480             Chinese Restaurant
# 6        -98.615297                           None
# 7        -98.592562           Fast Food Restaurant
# 8        -98.596107            American Restaurant
# 9        -98.586757          Vietnamese Restaurant
# 10       -98.591819                 Breakfast Spot
# 11       -98.624016                    Pizza Place
# 12       -98.634743             Mexican Restaurant
# 13       -98.596521            American Restaurant
# 14       -98.593224             Mexican Restaurant
# 15       -98.588456                Thai Restaurant
# 16       -98.584509                 Sandwich Place
# 17       -98.459227            American Restaurant
# 18       -98.465207            American Restaurant
# 19       -98.481566                       Wine Bar
# 20       -98.447968        New American Restaurant
# 21       -98.466408                          Diner
# 22       -98.490705                            Bar
# 23       -98.478802                     Restaurant
# 24       -98.458001               Asian Restaurant
# 25       -98.429588             Mexican Restaurant
# 26       -98.456878                         Lounge
# 27       -98.472042             Mexican Restaurant
# 28       -98.453156                           Food
# 29       -98.434046                         Bakery
# 30       -98.449089                           None
# 31       -98.449997             Chinese Restaurant
# 32       -98.476688          General Entertainment
# 33       -98.479339               Sushi Restaurant
# 34       -98.448125                Thai Restaurant
# 35       -98.456596             Mexican Restaurant
# 36       -98.437827            American Restaurant
# 37       -98.458520  Vegetarian / Vegan Restaurant
# 38       -98.475417             Italian Restaurant
# 39       -98.440084             Mexican Restaurant
# 40       -98.466103              French Restaurant
# 41       -98.444538             Mexican Restaurant
# 42       -98.442827                           None
# 43       -98.470461             Mexican Restaurant
# 44       -98.476764            Sporting Goods Shop
# 45       -98.467342              French Restaurant
# 46       -98.492340             Chinese Restaurant
# 47       -98.479960             Italian Restaurant
# 48       -98.488695                           Food
# 49       -98.479821               Greek Restaurant

# %%
def getNearbyVenues_explore(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Borough Latitude', 
                  'Borough Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
df
# 24       Twin Peaks Restaurant       29.562585       -98.591814
# 25       HuHot Mongolian Grill       29.561438       -98.591706
# 26        Picnikins Patio Cafe       29.571870       -98.596963
# 27                       H-E-B       29.562060       -98.588102
# 28                 Whataburger       29.563639       -98.592238
# 29                      Spec's       29.565675       -98.587210
#
#           Venue Category
# 0         Ice Cream Shop
# 1             Nail Salon
# 2                   Park
# 3                  Trail
# 4     Italian Restaurant
# 5          Deli / Bodega
# 6         Ice Cream Shop
# 7       Sushi Restaurant
# 8   Fast Food Restaurant
# 9       Sushi Restaurant
# 10           Pizza Place
# 11          Burger Joint
# 12              Pharmacy
# 13            Donut Shop
# 14    Mexican Restaurant
# 15           Beer Garden
# 16                  Park
# 17            Restaurant
# 18       Warehouse Store
# 19   Japanese Restaurant
# 20       Warehouse Store
# 21                 Trail
# 22            Bagel Shop
# 23           Coffee Shop
# 24   American Restaurant
# 25  Mongolian Restaurant
# 26                  Café
# 27         Grocery Store
# 28          Burger Joint
# 29          Liquor Store

# %%
df_explore['Venue Category'].unique()

sights = ['Historic Site','History Museum','Trail']

# %%
search_query = 'museum'
df_museum = getNearbyVenues(df_hood.Neighborhood, df_hood.Latitude, df_hood.Longitude, search_query, LIMIT, radius=8000)
df_museum.head()
# Out:
# Northwest Side
# Uptown
# Southside
# Midtown
# North Central
# Alamo Heights
# East Side
# Near East Side
# Downtown
#      Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0  Northwest Side               29.557154               -98.614671
# 1          Uptown               29.507220               -98.462190
# 2          Uptown               29.507220               -98.462190
# 3          Uptown               29.507220               -98.462190
# 4          Uptown               29.507220               -98.462190
#
#                                    Venue  Venue Latitude  Venue Longitude  \
# 0  Holocaust Memorial Museum San Antonio       29.556899       -98.533308
# 1                       McNay Art Museum       29.485617       -98.456265
# 2        McNay Art Museum Stieren Center       29.485668       -98.456248
# 3              San Antonio Museum of Art       29.437324       -98.482115
# 4             Buckhorn Saloon and Museum       29.426340       -98.488814
#
#         Venue Category
# 0       History Museum
# 1           Art Museum
# 2          Art Gallery
# 3               Museum
# 4  Monument / Landmark

# %%
df_museum
df_museum['Venue Category'].unique()
museum_cat = ['Museum','History Museum','Art Museum','Art Gallery','Cultural Center','Park','Monument / Landmark','Trail','Historic Site','Military Base']

df_museum = df_museum.loc[df_museum['Venue Category'].isin(museum_cat)]
df_museum.head(50)
# Out:
#       Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0   Northwest Side               29.557154               -98.614671
# 1           Uptown               29.507220               -98.462190
# 2           Uptown               29.507220               -98.462190
# 3           Uptown               29.507220               -98.462190
# 4           Uptown               29.507220               -98.462190
# 5           Uptown               29.507220               -98.462190
# 6           Uptown               29.507220               -98.462190
# 7           Uptown               29.507220               -98.462190
# 8           Uptown               29.507220               -98.462190
# 9           Uptown               29.507220               -98.462190
# 12          Uptown               29.507220               -98.462190
# 13          Uptown               29.507220               -98.462190
# 15          Uptown               29.507220               -98.462190
# 17          Uptown               29.507220               -98.462190
# 19          Uptown               29.507220               -98.462190
# 21          Uptown               29.507220               -98.462190
# 22          Uptown               29.507220               -98.462190
# 43                             McNay Art Museum       29.485617
# 44                       US Army Medical Museum       29.461390
# 46                Museum Reach River Walk Trail       29.443605
# 47              McNay Art Museum Stieren Center       29.485668
# 48                                 AMEDD Museum       29.466379
# 51                        O. Henry house museum       29.424386
# 52                                 Alamo Museum       29.425796
# 53                      Fort Sam Houston Museum       29.447540
# 54                Guinness World Records Museum       29.425982
# 55                          Texas Ranger Museum       29.426428
# 56             Children's Museum of San Antonio       29.426444
# 57                    San Antonio Museum of Art       29.425319
# 58                Edward Steve Homestead Museum       29.412668
# 59                               History Museum       29.425468
#
#     Venue Longitude       Venue Category
# 0        -98.533308       History Museum
# 1        -98.456265           Art Museum
# 2        -98.456248          Art Gallery
# 3        -98.482115               Museum
# 4        -98.488814  Monument / Landmark
# 5        -98.466774       History Museum
# 6        -98.449516       History Museum
# 7        -98.481302                 Park
# 8        -98.484118       History Museum
# 9        -98.456307           Art Museum
# 12       -98.481053                Trail
# 13       -98.435277  Monument / Landmark
# 15       -98.456327       History Museum
# 17       -98.467127       History Museum
# 19       -98.486077       History Museum
# 21       -98.486792               Museum
# 22       -98.533308       History Museum
# 23       -98.488846       History Museum
# 24       -98.489496               Museum
# 25       -98.486659               Museum
# 26       -98.449573        Military Base
# 27       -98.489066           Art Museum
# 28       -98.476046       History Museum
# 30       -98.495144          Art Gallery
# 31       -98.495188               Museum
# 32       -98.497575       History Museum
# 33       -98.489673               Museum
# 34       -98.488799               Museum
# 35       -98.490868           Art Museum
# 36       -98.488762           Art Museum
# 37       -98.486371        Historic Site
# 38       -98.482115               Museum
# 39       -98.481302                 Park
# 40       -98.488814  Monument / Landmark
# 41       -98.484118       History Museum
# 42       -98.489066           Art Museum
# 43       -98.456265           Art Museum
# 44       -98.466774       History Museum
# 46       -98.481053                Trail
# 47       -98.456248          Art Gallery
# 48       -98.449516       History Museum
# 51       -98.497575       History Museum
# 52       -98.486077       History Museum
# 53       -98.467127       History Museum
# 54       -98.486792               Museum
# 55       -98.488846       History Museum
# 56       -98.489496               Museum
# 57       -98.488762           Art Museum
# 58       -98.495188               Museum
# 59       -98.486371        Historic Site

# %%
search_query = 'sport'
df_sport = getNearbyVenues(df_hood.Neighborhood, df_hood.Latitude, df_hood.Longitude, search_query, LIMIT, radius=3000)
df_sport.head()
# Out:
# Northwest Side
# Uptown
# Southside
# Midtown
# North Central
# Alamo Heights
# East Side
# Near East Side
# Downtown
#      Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0  Northwest Side               29.557154               -98.614671
# 1  Northwest Side               29.557154               -98.614671
# 2  Northwest Side               29.557154               -98.614671
# 3  Northwest Side               29.557154               -98.614671
# 4  Northwest Side               29.557154               -98.614671
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0            Paris Sports Bar       29.556310       -98.614726
# 1  Cantina Sports Bar & Grill       29.556337       -98.614462
# 2       Sportsman's Warehouse       29.580245       -98.622464
# 3                 Good Sports       29.561869       -98.592948
# 4          Good Sports Outlet       29.573605       -98.588029
#
#         Venue Category
# 0           Sports Bar
# 1                  Bar
# 2  Sporting Goods Shop
# 3  Sporting Goods Shop
# 4  Sporting Goods Shop

# %%
df_sport
# Out:
#        Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0    Northwest Side               29.557154               -98.614671
# 1    Northwest Side               29.557154               -98.614671
# 2    Northwest Side               29.557154               -98.614671
# 3    Northwest Side               29.557154               -98.614671
# 4    Northwest Side               29.557154               -98.614671
# ..              ...                     ...                      ...
# 134        Downtown               29.425719               -98.489202
# 135        Downtown               29.425719               -98.489202
# 136        Downtown               29.425719               -98.489202
# 137        Downtown               29.425719               -98.489202
# 138        Downtown               29.425719               -98.489202
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0                  Paris Sports Bar       29.556310       -98.614726
# 1        Cantina Sports Bar & Grill       29.556337       -98.614462
# 2             Sportsman's Warehouse       29.580245       -98.622464
# 3                       Good Sports       29.561869       -98.592948
# 4                Good Sports Outlet       29.573605       -98.588029
# ..                              ...             ...              ...
# 134              Reina's Sports Bar       29.419310       -98.526302
# 135            Broadway  Sports Bar       29.448894       -98.475228
# 136             Otra Vez Sports Bar       29.390326       -98.503672
# 137          Antioch Sports Complex       29.426759       -98.452404
# 138  The HAWK Sports Bar at Pegasus       29.442083       -98.493949
#
#            Venue Category
# 0              Sports Bar
# 1                     Bar
# 2     Sporting Goods Shop
# 3     Sporting Goods Shop
# 4     Sporting Goods Shop
# ..                    ...
# 134                   Bar
# 135            Sports Bar
# 136                   Bar
# 137  Gym / Fitness Center
# 138          Cocktail Bar
#
# [139 rows x 7 columns]

# %%
#AT&T center coordinates
coord_att =[29.426809, -98.437391]

# %% [markdown]
# As described above, we are going to focus on the mexican restaurants in San Antonio.

# %%
df_mex_food = df_food[df_food['Venue Category'] == 'Mexican Restaurant']
df_mex_food
# Out:
#        Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0    Northwest Side               29.557154               -98.614671
# 1    Northwest Side               29.557154               -98.614671
# 2    Northwest Side               29.557154               -98.614671
# 4    Northwest Side               29.557154               -98.614671
# 12   Northwest Side               29.557154               -98.614671
# ..              ...                     ...                      ...
# 188        Downtown               29.425719               -98.489202
# 201        Downtown               29.425719               -98.489202
# 203        Downtown               29.425719               -98.489202
# 204        Downtown               29.425719               -98.489202
# 205        Downtown               29.425719               -98.489202
#
#                                     Venue  Venue Latitude  Venue Longitude  \
# 0        Los Jalapenos Mexican Restaurant       29.543234       -98.613792
# 1               Rico's Mexican Restaurant       29.555711       -98.614597
# 2             Don Jose Mexican Restaurant       29.554323       -98.615431
# 4                      Tommy’s Restaurant       29.565912       -98.593985
# 12                Taqueria Aguascalientes       29.587625       -98.634743
# ..                                    ...             ...              ...
# 188             Acenar Mexican Restaurant       29.426457       -98.491919
# 201  Estela's Mexican Restaurant & Bakery       29.430780       -98.516988
# 203             Diony's Sunset Restaurant       29.425546       -98.494779
# 204                 Tommy's Restaurant #1       29.401442       -98.511170
# 205        El Castillo Mexican Restaurant       29.422052       -98.491647
#
#          Venue Category                  Venue ID
# 0    Mexican Restaurant  4b7ff425f964a520a54630e3
# 1    Mexican Restaurant  4ff327ece4b0f1c616d33fb2
# 2    Mexican Restaurant  4f44ab7919836ed00195b2e8
# 4    Mexican Restaurant  5a96c81967e5f23b82f51ecd
# 12   Mexican Restaurant  4b59a28cf964a520199028e3
# ..                  ...                       ...
# 188  Mexican Restaurant  4ae3bd69f964a520979821e3
# 201  Mexican Restaurant  4b815e98f964a520fba130e3
# 203  Mexican Restaurant  4e73695caeb74f9f493d002c
# 204  Mexican Restaurant  4b4a1b02f964a520c27a26e3
# 205  Mexican Restaurant  5cd1c687e7a237002c535e6b
#
# [82 rows x 8 columns]

# %%
df_mex_food.groupby('Neighborhood').count()
# Out:
#                 Neighrborhood Latitude  Neighrborhood Longitude  Venue  \
# Neighborhood
# Alamo Heights                        5                        5      5
# Downtown                             8                        8      8
# East Side                           15                       15     15
# Midtown                             15                       15     15
# Near East Side                       5                        5      5
# North Central                       13                       13     13
# Northwest Side                       6                        6      6
# Southside                           10                       10     10
# Uptown                               5                        5      5
#
#                 Venue Latitude  Venue Longitude  Venue Category  Venue ID
# Neighborhood
# Alamo Heights                5                5               5         5
# Downtown                     8                8               8         8
# East Side                   15               15              15        15
# Midtown                     15               15              15        15
# Near East Side               5                5               5         5
# North Central               13               13              13        13
# Northwest Side               6                6               6         6
# Southside                   10               10              10        10
# Uptown                       5                5               5         5

# %%
#I ran out of premium call quota.

venue_rating = []
venue_tips = []

counter = 0

for venue_id in df_mex_food['Venue ID'].values:
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    
    try:
        rating  = result['response']['venue']['rating']
    except:
        rating = -1
    try:
        tips = result['response']['venue']['tips']['count']
    except:
        tips = 0
    
    venue_rating.append(rating)
    venue_tips.append(tips)
    
    counter += 1
    
    if counter % 10 == 0:
        print("Counter is now "+ str(counter))

df_mex_food['Venue Rating'] = venue_rating
df_mex_food['Venue Tips'] = venue_tips

df_mex_food
# Out:
# Counter is now 10
# Counter is now 20
# Counter is now 30
# Counter is now 40
# Counter is now 50
# Counter is now 60
# Counter is now 70
# Counter is now 80
# <ipython-input-45-08e2959593d2>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mex_food['Venue Rating'] = venue_rating
# <ipython-input-45-08e2959593d2>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mex_food['Venue Tips'] = venue_tips
#        Neighborhood  Neighrborhood Latitude  Neighrborhood Longitude  \
# 0    Northwest Side               29.557154               -98.614671
# 1    Northwest Side               29.557154               -98.614671
# 2    Northwest Side               29.557154               -98.614671
# 4    Northwest Side               29.557154               -98.614671
# 12   Northwest Side               29.557154               -98.614671
# ..              ...                     ...                      ...
# 188        Downtown               29.425719               -98.489202
# 201        Downtown               29.425719               -98.489202
# 203        Downtown               29.425719               -98.489202
# 204        Downtown               29.425719               -98.489202
# 205        Downtown               29.425719               -98.489202
#
#                                     Venue  Venue Latitude  Venue Longitude  \
# 0        Los Jalapenos Mexican Restaurant       29.543234       -98.613792
# 1               Rico's Mexican Restaurant       29.555711       -98.614597
# 2             Don Jose Mexican Restaurant       29.554323       -98.615431
# 4                      Tommy’s Restaurant       29.565912       -98.593985
# 12                Taqueria Aguascalientes       29.587625       -98.634743
# ..                                    ...             ...              ...
# 188             Acenar Mexican Restaurant       29.426457       -98.491919
# 201  Estela's Mexican Restaurant & Bakery       29.430780       -98.516988
# 203             Diony's Sunset Restaurant       29.425546       -98.494779
# 204                 Tommy's Restaurant #1       29.401442       -98.511170
# 205        El Castillo Mexican Restaurant       29.422052       -98.491647
#
#          Venue Category                  Venue ID  Venue Rating  Venue Tips
# 0    Mexican Restaurant  4b7ff425f964a520a54630e3            -1           0
# 1    Mexican Restaurant  4ff327ece4b0f1c616d33fb2            -1           0
# 2    Mexican Restaurant  4f44ab7919836ed00195b2e8            -1           0
# 4    Mexican Restaurant  5a96c81967e5f23b82f51ecd            -1           0
# 12   Mexican Restaurant  4b59a28cf964a520199028e3            -1           0
# ..                  ...                       ...           ...         ...
# 188  Mexican Restaurant  4ae3bd69f964a520979821e3            -1           0
# 201  Mexican Restaurant  4b815e98f964a520fba130e3            -1           0
# 203  Mexican Restaurant  4e73695caeb74f9f493d002c            -1           0
# 204  Mexican Restaurant  4b4a1b02f964a520c27a26e3            -1           0
# 205  Mexican Restaurant  5cd1c687e7a237002c535e6b            -1           0
#
# [82 rows x 10 columns]

# %%
venues_map = folium.Map(location=[latitude_SA, longitude_SA], zoom_start=10)

for lat, lng, label in zip(df_mex_food['Venue Latitude'], df_mex_food['Venue Longitude'], df_mex_food['Venue']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        #popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
    
for lat, lng, label in zip(df_museum['Venue Latitude'], df_museum['Venue Longitude'], df_museum['Venue']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        #popup=label,
        fill=True,
        color='yellow',
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(venues_map)

for lat, lng, label in zip(df_hood['Latitude'], df_hood['Longitude'], df_hood['Neighborhood']):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)
    
folium.CircleMarker(
    [coord_att[0],coord_att[1]],
    radius = 8,
    popup = "AT&T Center",
    fill = True,
    color = "cyan",
    fill_color = 'cyan',
    fill_opacity = 0.6).add_to(venues_map)

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def calculate_score(lat_neigh, lng_neigh, df):
    
    #We are using recriprocal scores. Can change to exponential score if desired.
    
    score = 0
    
    lats = df['Venue Latitude'].values
    lngs = df['Venue Longitude'].values
    
    for lat,lng in zip(lats, lngs):
        dist = np.sqrt((lat_neigh - lat)**2 + (lng_neigh-lng)**2)
        score += 1/dist
        
    return score

# %%
score_food = []
score_museum = []
score_ATT = []

lat_neighs = df_hood.Latitude.values
lng_neighs = df_hood.Longitude.values
name_neighs = df_hood.Neighborhood.values

for lat_neigh, lng_neigh, name_neigh in zip(lat_neighs, lng_neighs, name_neighs):
    
    score_food.append(calculate_score(lat_neigh, lng_neigh, df_mex_food))
    score_museum.append(calculate_score(lat_neigh, lng_neigh, df_museum))
    
    dist_to_att = np.sqrt((lat_neigh - coord_att[0])**2 + (lng_neigh - coord_att[1])**2)
    score_ATT.append(1/dist_to_att**(0.5))

    print("Finished calculating scores for", name_neigh)

df_hood['Food Score'] = score_food
df_hood['Museum Score'] = score_museum
df_hood['NBA Score'] = score_ATT

df_hood
# Out:
# Finished calculating scores for Northwest Side
# Finished calculating scores for Uptown
# Finished calculating scores for Southside
# Finished calculating scores for Midtown
# Finished calculating scores for North Central
# Finished calculating scores for Alamo Heights
# Finished calculating scores for East Side
# Finished calculating scores for Near East Side
# Finished calculating scores for Downtown
#      Neighborhood   Latitude  Longitude   Food Score  Museum Score  NBA Score
# 0  Northwest Side  29.557154 -98.614671  1663.406469   1024.841709   2.131809
# 1          Uptown  29.507220 -98.462190  1199.440030   3035.066992   3.447288
# 2       Southside  29.333650 -98.524594   929.442322   1697.822460   2.799411
# 3         Midtown  29.453459 -98.494632  1920.139336   5895.141382   3.979665
# 4   North Central  29.497288 -98.525972  1622.915122   2304.650287   2.972212
# 5   Alamo Heights  29.483226 -98.468455  1392.274976   4810.777408   3.940425
# 6       East Side  29.406447 -98.418599  1336.099893   2513.974042   6.007517
# 7  Near East Side  29.441394 -98.450757  1450.251296   5781.555631   7.109720
# 8        Downtown  29.425719 -98.489202  3754.280032  57527.759027   4.392782

# %%
# Calculate relative scores

df_hood['Food Score'] = df_hood['Food Score']/df_hood['Food Score'].values.max()
df_hood['Museum Score'] = df_hood['Museum Score']/df_hood['Museum Score'].values.max()
df_hood['NBA Score'] = df_hood['NBA Score']/df_hood['NBA Score'].values.max()

df_hood
# Out:
#      Neighborhood   Latitude  Longitude  Food Score  Museum Score  NBA Score
# 0  Northwest Side  29.557154 -98.614671    0.443069      0.017815   0.299844
# 1          Uptown  29.507220 -98.462190    0.319486      0.052758   0.484870
# 2       Southside  29.333650 -98.524594    0.247569      0.029513   0.393744
# 3         Midtown  29.453459 -98.494632    0.511453      0.102475   0.559750
# 4   North Central  29.497288 -98.525972    0.432284      0.040062   0.418049
# 5   Alamo Heights  29.483226 -98.468455    0.370850      0.083625   0.554231
# 6       East Side  29.406447 -98.418599    0.355887      0.043700   0.844972
# 7  Near East Side  29.441394 -98.450757    0.386293      0.100500   1.000000
# 8        Downtown  29.425719 -98.489202    1.000000      1.000000   0.617856

# %% [markdown]
# With this done, we can calculate the most recommended neighborhood based on the interests.

# %%
def best_neigh(weights, df_hood):
    
    score_list = (weights[0] * df_hood['Food Score'] + weights[1] * df_hood['Museum Score'] + weights[2] * df_hood['NBA Score']).values
    
    ind = score_list.argmax()
    
    
    return df_hood.loc[ind, 'Neighborhood']

Weights = [1,0.3,7]

weight_string = "("+ ", ".join(map(str, Weights)) + ")"

print("The best neighborhood based on interest weight {} is {}".format(weight_string, best_neigh(Weights, df_hood)))

Weights = [0.5,1,2]

weight_string = "("+ ", ".join(map(str, Weights)) + ")"

print("The best neighborhood based on interest weight {} is {}".format(weight_string, best_neigh(Weights, df_hood)))

Weights = [0,1,3]

weight_string = "("+ ", ".join(map(str, Weights)) + ")"

print("The best neighborhood based on interest weight {} is {}".format(weight_string, best_neigh(Weights, df_hood)))
# Out:
# The best neighborhood based on interest weight (1, 0.3, 7) is Near East Side
# The best neighborhood based on interest weight (0.5, 1, 2) is Downtown
# The best neighborhood based on interest weight (0, 1, 3) is Near East Side
